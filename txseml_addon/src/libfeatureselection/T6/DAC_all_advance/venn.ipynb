# %%
import json
from src.utils import pyvenn as venn

# %%
with open("src/libfeatureselection/T6/DAC_all_advance/dac.json", "r", encoding="UTF-8") as f:
    db = json.load(f)

# %%
print("AE_AB", len(set(db['AB']) & set(db['AE'])))
print("TT_AE", len(set(db['TT']) & set(db['AE'])))
print("TT_AB", len(set(db['TT']) & set(db['AB'])))
# Out:
# AE_AB 20
# TT_AE 25
# TT_AB 24

# %%
key_list = list(db.keys())

# %%
labels = venn.get_labels([ db[k] for k in key_list], fill=['number','percent'])
fig, ax = venn.venn3(labels, names=key_list, )
fig.show()
